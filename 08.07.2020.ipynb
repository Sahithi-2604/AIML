# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = plt.imread("C:/Users/sahithi/Desktop/aiandml/python/minion.jpg")
print(img.shape)
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)

# %%
#Image with one dimension
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
plt.imshow(img[:,:125,:])
