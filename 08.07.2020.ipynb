# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = plt.imread("C:/Users/sahithi/Desktop/aiandml/python/photo.jpg")
print(img.shape)
# Out:
# (1000, 1000, 3)

# %%
plt.imshow(img)

# %%
#Image with one dimension
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
plt.imshow(img[:,:300,:])
